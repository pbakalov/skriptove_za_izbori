# %%
#coding=utf-8
import matplotlib.pylab as plt
# import seaborn as sb
from numpy import arange
# import plotly.graph_objects as go
import pandas as pd

#plt.ion()

from izbori_utils import  get_filtered_results_by_station , load_station_ids


station_ids =  load_station_ids('sections_03.11.2019.txt', 2246) # 2246 = Столична община (22 = код на район, 46 = код на община)

results_by_station, maya, fanduk, x_pos, width, extreme_ids = get_filtered_results_by_station("votes_03.11.2019.txt", station_ids)

print "reading addresses"
adresi = pd.read_excel('./Sekcii-08.09.2019-KM-0.xlsx')
print "addresses read"
#print adresi.head()
sofia_sections = adresi['Област код'.decode('utf-8')] == 22
sofia_sections.head()
# Out:
# 1 224607070 407 68
# 2 224607071 507 46
# 3 224607072 394 47
# 4 224607074 357 60
# 5 224607076 368 51
# 6 224607077 421 74
# 7 224611056 128 22
# 8 224611058 153 35
# 9 224611061 323 26
# 10 224611062 256 24
# 11 224611064 290 32
# 12 224611065 276 29
# 13 224611071 202 35
# 14 224611074 187 21
# 15 224611075 161 12
# 16 224611076 137 16
# 17 224619071 305 43
# 18 224619072 372 34
# 19 224619132 328 50
# (42.857142857142854, 57.142857142857146, 14)
# 1611 1611
# [11, 75, 10]
# [0, 11, 86]
# [397643, 398196, 398545]
# fanduk, maya
# 209542 189176
# 398718
# extreme votes 5572
# extreme diff 4847
# extreme stations 19
# reading addresses
# addresses read
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Област код, dtype: bool

# %%
# izbrani_adresi = pd.DataFrame()
for i, section_id in enumerate(extreme_ids[1:]):
    #region = section_id[:2]
    #municipality = section_id[2:4]
    adm_reg = section_id[4:6]
    section = section_id[6:]
#     print section_id, adresi[sofia_sections  & (adresi['Община код'.decode('utf-8')]==46) \
#                              & (adresi['Район код'.decode('utf-8')]== int(adm_reg)) \
#                              & (adresi['Секция'.decode('utf-8')]  == int(section))]#['Адрес'.decode('utf-8')]
    
#     print section_id
    if i == 0: 
        izbrani_adresi = adresi[sofia_sections  & (adresi['Община код'.decode('utf-8')]==46)\
                                 & (adresi['Район код'.decode('utf-8')]== int(adm_reg)) \
                                 & (adresi['Секция'.decode('utf-8')]  == int(section))]
    else:
        izbrani_adresi = izbrani_adresi.append(adresi[sofia_sections  & (adresi['Община код'.decode('utf-8')]==46)\
                                 & (adresi['Район код'.decode('utf-8')]== int(adm_reg)) \
                                 & (adresi['Секция'.decode('utf-8')]  == int(section))], ignore_index=True)
    


    

izbrani_adresi
# Out:
#     Област код Област текст  Община код    Община  Район код          Район  \
# 0           22        СОФИЯ          46  СТОЛИЧНА        7.0        СЛАТИНА
# 1           22        СОФИЯ          46  СТОЛИЧНА        7.0        СЛАТИНА
# 2           22        СОФИЯ          46  СТОЛИЧНА        7.0        СЛАТИНА
# 3           22        СОФИЯ          46  СТОЛИЧНА        7.0        СЛАТИНА
# 4           22        СОФИЯ          46  СТОЛИЧНА        7.0        СЛАТИНА
# 5           22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 6           22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 7           22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 8           22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 9           22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 10          22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 11          22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 12          22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 13          22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 14          22        СОФИЯ          46  СТОЛИЧНА       11.0  КРАСНА ПОЛЯНА
# 15          22        СОФИЯ          46  СТОЛИЧНА       19.0          ЛЮЛИН
# 16          22        СОФИЯ          46  СТОЛИЧНА       19.0          ЛЮЛИН
# 17          22        СОФИЯ          46  СТОЛИЧНА       19.0          ЛЮЛИН
#
#     Секция  Населено място код          Населено място  \
# 0       71               68134                ГР.СОФИЯ
# 1       72               68134                ГР.СОФИЯ
# 2       74               68134                ГР.СОФИЯ
# 3       76               68134                ГР.СОФИЯ
# 4       77               68134                ГР.СОФИЯ
# 5       56               68134                ГР.СОФИЯ
# 6       58               68134                ГР.СОФИЯ
# 7       61               68134                ГР.СОФИЯ
# 8       62               68134                ГР.СОФИЯ
# 9       64               68134                ГР.СОФИЯ
# 10      65               68134                ГР.СОФИЯ
# 11      71               68134                ГР.СОФИЯ
# 12      74               68134                ГР.СОФИЯ
# 13      75               68134                ГР.СОФИЯ
# 14      76               68134                ГР.СОФИЯ
# 15      71               97149  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ
# 16      72               97149  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ
# 17     132               97149  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ
#
#                                         Адрес
# 0     94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 1     94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 2     94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 3     94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 4     94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 5               123 СОУ, ул. "Братин дол" №26
# 6   92 ОУ "Димитър Талев", ул. "Добротич" №21
# 7                     75 ОУ , кв. "Факултета"
# 8                     75 ОУ , кв. "Факултета"
# 9                     75 ОУ , кв. "Факултета"
# 10                    75 ОУ , кв. "Факултета"
# 11                    75 ОУ , кв. "Факултета"
# 12                    75 ОУ , кв. "Факултета"
# 13        92 ОУ "Д.Талев", ул."Добротич" № 21
# 14              123 СОУ, ул. "Братин дол" №26
# 15      103 ОУ "Васил Левски", ж.к. Филиповци
# 16      103 ОУ "Васил Левски", ж.к. Филиповци
# 17      103 ОУ "Васил Левски", ж.к. Филиповци

# %%
del izbrani_adresi['Населено място код'.decode('utf-8')]

# %%
izbrani_adresi['Район код'.decode('utf-8')] = izbrani_adresi['Район код'.decode('utf-8')].apply(lambda x: str(int(x)).zfill(2))
izbrani_adresi['Секция'.decode('utf-8')] = izbrani_adresi['Секция'.decode('utf-8')].apply(lambda x: str(int(x)).zfill(3))
izbrani_adresi =  izbrani_adresi.rename(columns = {'Област текст'.decode('utf-8'):'Област'.decode('utf-8')} )

izbrani_adresi
# Out:
#     Област код Област  Община код    Община Район код          Район Секция  \
# 0           22  СОФИЯ          46  СТОЛИЧНА        07        СЛАТИНА    071
# 1           22  СОФИЯ          46  СТОЛИЧНА        07        СЛАТИНА    072
# 2           22  СОФИЯ          46  СТОЛИЧНА        07        СЛАТИНА    074
# 3           22  СОФИЯ          46  СТОЛИЧНА        07        СЛАТИНА    076
# 4           22  СОФИЯ          46  СТОЛИЧНА        07        СЛАТИНА    077
# 5           22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    056
# 6           22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    058
# 7           22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    061
# 8           22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    062
# 9           22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    064
# 10          22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    065
# 11          22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    071
# 12          22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    074
# 13          22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    075
# 14          22  СОФИЯ          46  СТОЛИЧНА        11  КРАСНА ПОЛЯНА    076
# 15          22  СОФИЯ          46  СТОЛИЧНА        19          ЛЮЛИН    071
# 16          22  СОФИЯ          46  СТОЛИЧНА        19          ЛЮЛИН    072
# 17          22  СОФИЯ          46  СТОЛИЧНА        19          ЛЮЛИН    132
#
#             Населено място                                      Адрес
# 0                 ГР.СОФИЯ    94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 1                 ГР.СОФИЯ    94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 2                 ГР.СОФИЯ    94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 3                 ГР.СОФИЯ    94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 4                 ГР.СОФИЯ    94 СУ,кв. "Хр.Ботев", ул. "511-та" № 22
# 5                 ГР.СОФИЯ              123 СОУ, ул. "Братин дол" №26
# 6                 ГР.СОФИЯ  92 ОУ "Димитър Талев", ул. "Добротич" №21
# 7                 ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 8                 ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 9                 ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 10                ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 11                ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 12                ГР.СОФИЯ                    75 ОУ , кв. "Факултета"
# 13                ГР.СОФИЯ        92 ОУ "Д.Талев", ул."Добротич" № 21
# 14                ГР.СОФИЯ              123 СОУ, ул. "Братин дол" №26
# 15  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ      103 ОУ "Васил Левски", ж.к. Филиповци
# 16  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ      103 ОУ "Васил Левски", ж.к. Филиповци
# 17  ГР.СОФИЯ,Ж.К.ФИЛИПОВЦИ      103 ОУ "Васил Левски", ж.к. Филиповци

# %%
from izbori_utils import generate_plots
plt.ion()

generate_plots()
# Out:
# 1 224607070 407 68
# 2 224607071 507 46
# 3 224607072 394 47
# 4 224607074 357 60
# 5 224607076 368 51
# 6 224607077 421 74
# 7 224611056 128 22
# 8 224611058 153 35
# 9 224611061 323 26
# 10 224611062 256 24
# 11 224611064 290 32
# 12 224611065 276 29
# 13 224611071 202 35
# 14 224611074 187 21
# 15 224611075 161 12
# 16 224611076 137 16
# 17 224619071 305 43
# 18 224619072 372 34
# 19 224619132 328 50
# (42.857142857142854, 57.142857142857146, 14)
# 1611 1611
# [11, 75, 10]
# [0, 11, 86]
# [397643, 398196, 398545]
# fanduk, maya
# 209542 189176
# 398718
# extreme votes 5572
# extreme diff 4847
# extreme stations 19

# %%
from izbori_utils import interactive_plot
interactive_plot()
# Out:
# 1 224607070 407 68
# 2 224607071 507 46
# 3 224607072 394 47
# 4 224607074 357 60
# 5 224607076 368 51
# 6 224607077 421 74
# 7 224611056 128 22
# 8 224611058 153 35
# 9 224611061 323 26
# 10 224611062 256 24
# 11 224611064 290 32
# 12 224611065 276 29
# 13 224611071 202 35
# 14 224611074 187 21
# 15 224611075 161 12
# 16 224611076 137 16
# 17 224619071 305 43
# 18 224619072 372 34
# 19 224619132 328 50
# (42.857142857142854, 57.142857142857146, 14)
# 1611 1611
# [11, 75, 10]
# [0, 11, 86]
# [397643, 398196, 398545]
# fanduk, maya
# 209542 189176
# 398718
# extreme votes 5572
# extreme diff 4847
# extreme stations 19

# %%
station_ids =  load_station_ids('sections_03.11.2019.txt', 2246) # 2246 = Столична община (22 = код на район, 46 = код на община)
results_by_station, maya, fanduk, x_pos, width, extreme_ids = get_filtered_results_by_station("votes_03.11.2019.txt", station_ids)
# Out:
# 1 224607070 407 68
# 2 224607071 507 46
# 3 224607072 394 47
# 4 224607074 357 60
# 5 224607076 368 51
# 6 224607077 421 74
# 7 224611056 128 22
# 8 224611058 153 35
# 9 224611061 323 26
# 10 224611062 256 24
# 11 224611064 290 32
# 12 224611065 276 29
# 13 224611071 202 35
# 14 224611074 187 21
# 15 224611075 161 12
# 16 224611076 137 16
# 17 224619071 305 43
# 18 224619072 372 34
# 19 224619132 328 50
# (42.857142857142854, 57.142857142857146, 14)
# 1611 1611
# [11, 75, 10]
# [0, 11, 86]
# [397643, 398196, 398545]
# fanduk, maya
# 209542 189176
# 398718
# extreme votes 5572
# extreme diff 4847
# extreme stations 19

# %%
import plotly.graph_objects as go
M=len(x_pos)
animals= x_pos[:M]#['giraffes', 'orangutans', 'monkeys']

fig = go.Figure(data=[
    go.Bar(name='Фандъкова'.decode('utf-8'), x=animals, width=width[:M], y=fanduk[:M],
           hovertext=adresi['Адрес'.decode('utf-8')]),
    go.Bar(name='Манолова'.decode('utf-8'), x=animals,  width=width[:M], y=maya[:M])
    ])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.write_html('section_results_bar_plot.html', auto_open=True)
